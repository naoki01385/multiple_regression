# 40          41  0.957778  0.528651  0.061374 -0.081413 -0.033043
# 41          42  0.972620  0.524775  0.052844 -0.092325 -0.044729
# 42          43  0.992887  0.501407  0.049430 -0.129698 -0.052914
# 43          44  1.021851  0.479650  0.022594 -0.200320 -0.105424
# 44          45  1.033338  0.461198  0.021960 -0.221431 -0.152525
# 45          46  1.070606  0.436020 -0.005233 -0.253583 -0.166034
# 46          47  1.100579  0.435511 -0.049720 -0.292634 -0.170011
# 47          48  1.321828  0.431165 -0.152341 -0.406457 -0.190316
# 48          49  1.360388  0.414584 -0.249847 -0.408695 -0.227004
# 49          50  1.378054  0.249701 -0.515320 -0.477564 -0.235319

# %%
scaler.fit(np.array(df)) # 標準化を適応
df_std = scaler.transform(np.array(df)) # 標準化する
df_std = pd.DataFrame(df_std, columns=df.columns) # データフレームに変換

# %%
y=df['data']
x=df[['data1','data2','data3','data4']]
X_con = sm.add_constant(x)

# %% [markdown]
# t値の絶対値が2より小さい場合は、統計的にその説明変数は目的変数に影響しない。
# P-値が0.05未満であれば、その説明変数は目的変数に対して「関係性がある」
# Fが0.05未満であれば、有用な回帰式を得られたと判断

# %%
scaler = StandardScaler()
model = sm.OLS(y, X_con) # モデルを作成
result = model.fit() # モデルを適応
result.summary() # 結果を確認
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   data   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     373.9
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           6.80e-34
# Time:                        19:46:23   Log-Likelihood:                 98.285
# No. Observations:                  50   AIC:                            -186.6
# Df Residuals:                      45   BIC:                            -177.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5391      0.099      5.467      0.000       0.341       0.738
# data1          0.7754      0.176      4.396      0.000       0.420       1.131
# data2         -0.3843      0.072     -5.302      0.000      -0.530      -0.238
# data3         -0.8672      0.090     -9.602      0.000      -1.049      -0.685
# data4          0.1726      0.197      0.875      0.386      -0.225       0.570
# ==============================================================================
# Omnibus:                        2.687   Durbin-Watson:                   0.722
# Prob(Omnibus):                  0.261   Jarque-Bera (JB):                1.910
# Skew:                           0.465   Prob(JB):                        0.385
# Kurtosis:                       3.230   Cond. No.                         69.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn.linear_model import LinearRegression

reg_model = LinearRegression(fit_intercept=True)
reg_result = reg_model.fit(x, y)

print(" r2: ", reg_model.score(x, y))
print(x.columns)
print(" Coef: ", reg_model.coef_)
print(" intercept: ", reg_model.intercept_)
# Out:
#  r2:  0.9707918177860787
# Index(['data1', 'data2', 'data3', 'data4'], dtype='object')
#  Coef:  [ 0.77541593 -0.38429216 -0.86724772  0.17263145]
#  intercept:  0.5391312863408453

# %%
regressor=RandomForestRegressor(n_estimators=10)

# %%
regressor.fit(X_con,y)
regressor.score(X_con,y)
y_pred=regressor.predict(X_con)
r2_score(y_pred,y)
# Out:
# 0.9950944770719984
